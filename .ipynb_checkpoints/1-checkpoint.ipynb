# %%
import pandas as pd

# %%
import pymysql
import sqlalchemy
from sqlalchemy import create_engine

# %%
data = pd.read_csv('parking.csv')
data.head()
# Out:
#    Unnamed: 0                                                WKT  \
# 0           0  POLYGON ((110677.64 492542.17,110672.28 492543...
# 1           1  POLYGON ((110683.02 492541.02,110677.64 492542...
# 2           2  POLYGON ((110683.44 492542.97,110690.81 492541...
# 3           3  POLYGON ((111725.48 491372.13,111724.98 491369...
# 4           4  POLYGON ((111725.98 491374.5,111725.48 491372....
#
#              ID        GEO_ID NEIGBORHOOD_CODE    URBAN_AREA  SREET_NAME  \
# 0  110675492544  110675492544             B10g  westpoort_nf  Abidjanweg
# 1  110681492543  110681492543             B10g  westpoort_nf  Abidjanweg
# 2  110687492541  110686492541             B10g  westpoort_nf  Abidjanweg
# 3  111723491371  111723491371             B10g  westpoort_nf    Ruigoord
# 4  111724491374  111724491374             B10g  westpoort_nf    Ruigoord
#
#    QUANTITY      CATEGORY   TYPE E_TYPE E_TYPE_DESC SIGN
# 0         1  NIET FISCAAL  Langs    NaN         NaN  NaN
# ...

# %%
data = data.drop(['ID', 'WKT', 'E_TYPE', 'E_TYPE_DESC', 'SIGN'], axis=1)
data.head()
# Out:
#    Unnamed: 0        GEO_ID NEIGBORHOOD_CODE    URBAN_AREA  SREET_NAME  \
# 0           0  110675492544             B10g  westpoort_nf  Abidjanweg
# 1           1  110681492543             B10g  westpoort_nf  Abidjanweg
# 2           2  110686492541             B10g  westpoort_nf  Abidjanweg
# 3           3  111723491371             B10g  westpoort_nf    Ruigoord
# 4           4  111724491374             B10g  westpoort_nf    Ruigoord
#
#    QUANTITY      CATEGORY   TYPE
# 0         1  NIET FISCAAL  Langs
# 1         1  NIET FISCAAL  Langs
# 2         1  NIET FISCAAL  Langs
# 3         1  NIET FISCAAL  Haaks
# 4         1  NIET FISCAAL  Haaks

# %%
data.to_csv('parking_new.csv', index=False)

# %%
new_data = data[['URBAN_AREA', 'GEO_ID']]
new_data['URBAN_AREA'] = new_data['URBAN_AREA'].str.replace('_nf', '')
new_data.head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   URBAN_AREA        GEO_ID
# 0  westpoort  110675492544
# 1  westpoort  110681492543
# 2  westpoort  110686492541
# 3  westpoort  111723491371
# 4  westpoort  111724491374
# 5  westpoort  111724491376
# 6  westpoort  111725491379
# 7  westpoort  111725491381
# 8  westpoort  111726491383
# 9  westpoort  111726491386

# %%
before = len(new_data)
lst = ['GEO_ID']
new_data = new_data[lst].drop_duplicates()
after = len(new_data)
print('Number of duplicate records dropped: ', str(before - after))
# Out:
# Number of duplicate records dropped:  0

# %%
westpoort = new_data[(new_data['URBAN_AREA'] == 'west')]
westpoort.head()
# Out:
#      URBAN_AREA        GEO_ID
# 268        west  118006487491
# 589        west  118058487547
# 621        west  118220489653
# 1344       west  118220489659
# 1434       west  118240489386

# %%
new_data1 = data[['URBAN_AREA', 'CATEGORY', 'GEO_ID']]
new_data1['URBAN_AREA'] = new_data1['URBAN_AREA'].str.replace('_nf', '')
new_data1.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   URBAN_AREA      CATEGORY        GEO_ID
# 0  westpoort  NIET FISCAAL  110675492544
# 1  westpoort  NIET FISCAAL  110681492543
# 2  westpoort  NIET FISCAAL  110686492541
# 3  westpoort  NIET FISCAAL  111723491371
# 4  westpoort  NIET FISCAAL  111724491374

# %%
data = data[['URBAN_AREA', 'GEO_ID', 'SREET_NAME']]
data
# Out:
#           URBAN_AREA        GEO_ID             SREET_NAME
# 0       westpoort_nf  110675492544             Abidjanweg
# 1       westpoort_nf  110681492543             Abidjanweg
# 2       westpoort_nf  110686492541             Abidjanweg
# 3       westpoort_nf  111723491371               Ruigoord
# 4       westpoort_nf  111724491374               Ruigoord
# 5       westpoort_nf  111724491376               Ruigoord
# 6       westpoort_nf  111725491379               Ruigoord
# 7       westpoort_nf  111725491381               Ruigoord
# 8       westpoort_nf  111726491383               Ruigoord
# 9       westpoort_nf  111726491386               Ruigoord
# 10      westpoort_nf  111726491388               Ruigoord
# 11      westpoort_nf  111727491390               Ruigoord
# 12      westpoort_nf  111727491393               Ruigoord
# 13      westpoort_nf  111728491395               Ruigoord
# 14      westpoort_nf  111728491397               Ruigoord
# ...
